# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
#If the version of Julia is OLDER than 0.6.9, comment out "using Distributed"
#using Distributed

# %%
if v"0.6.9" <= VERSION  #The version of Julia is higher than 0.6.9
    using InteractiveUtils    
    @everywhere using SparseArrays
    @everywhere using LinearAlgebra
    @everywhere include("SS_p.jl")
    @everywhere import .SS
    @everywhere using Random
    Random.seed!(1234)
else #The version of Julia is older than 0.6.9
    
    @everywhere include("SS_p.jl")
    @everywhere import SS 
    srand(1234)
end
versioninfo()




@everywhere function make_1Dtb(N,periodic=true) #1D tight binding model
    mat_H = spzeros(N,N)
    t = 1.0
    
    for i in 1:N
        for dx in -1:1
            j = i + dx
            if periodic
                if j > N
                    j = j -N
                elseif j < 1
                    j = j +N
                end
            end
            
            if 1 <= j <= N
                if dx == 1
                    mat_H[i,j] = -t
                elseif dx == -1
                    mat_H[i,j] = -t
                elseif dx ==0
                    mat_H[i,j] = 1.5
                end
                    
            end
            
        end
    end
    
    return mat_H
end


@everywhere function make_2Dtb(Nx,Ny,periodic=true) #2D tight binding model
    mat_H = spzeros(Nx*Ny,Nx*Ny)
    t = 1.0
    μ = -1.5
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end
                        i = (iy-1)*Nx+ix
                        j = (jy-1)*Ny+jx
                        mat_H[i,j] = v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end


@everywhere function make_2Dtbsc(Nx,Ny,periodic=true) #2D tight binding model with superconducting SNS π junction
    mat_H = spzeros(Nx*Ny*2,Nx*Ny*2)
    N = Nx*Ny
    t = 1.0
    μ = -1.5
    Δ = 1.0
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    i = (iy-1)*Nx+ix
                    j = (jy-1)*Ny+jx
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ                                
                                vd = ifelse(jx < Nx/2,Δ,-Δ)
                                
                                if Nx/2-Nx/6 <= jx <= Nx/2 + Nx/6
                                  vd = 0.0  
                                end
                                mat_H[i,j+N] = vd
                                mat_H[i+N,j] = vd                                   
                                    
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end

                        mat_H[i,j] = v
                        mat_H[i+N,j+N] = -v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end




@everywhere function main()
    Nx = 12
    Ny = 12

    
    ρ = 0.2
    γ = 0.0
    ε =0
#    mat_H = make_1Dtb(N) #1D system
    N = Nx*Ny
#    mat_H = make_2Dtb(Nx,Ny,false) #2D system
    N = Nx*Ny*2
    mat_H = make_2Dtbsc(Nx,Ny,false) #2D system with superconducting SNS π-junction
    
    println("Dimension of the matrix: ",N)
    rε = Float64[]
    if N <= 8192
        println("Doing the full diagonalization...")
        if v"0.6.9" <= VERSION
            @time ε,vec_w = eigen(Matrix(mat_H))
        else
            @time ε,vec_w = eig(full(mat_H))
        end
        println("Done")
        

        integers = Int64[]
        for i in 1:N
            push!(integers,i)
        end      
        
        
        rε = Float64[]
        is = 0
        for i in 1:N
            if γ-ρ <= ε[i] <= γ+ρ
                is += 1
                push!(rε,ε[i])
            end
        end         
    end
   

   

    #println(ε)
    if N < 2000
      
        for i in 1:is
            println(i, "       ",rε[i])
        end
       
        
    end
    

    
    #println(typeof(mat_H[1,1]))
    println("Doing the SS method...")
    @time eigenvalues,residuals,eigenvectors,num = SS.eigensystem(mat_H,N,ρ,γ)
    println("done.")
    
    if N <= 8192
        println("number    eigenvalue    residual    original     difference")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i],"     ",rε[i], "    ",eigenvalues[i]-rε[i])
        end
    else
        println("number    eigenvalue    residual    ")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i])
        end        
    end
    println("-----------------------------------------") 
#plot(integers[:],ε[:],label="Original") 
#    plot(integers[1:num],eigenvalues[1:num],label="SS method") 

#    plot(integers[1:N],ε[1:N],label="Original")      
    
    return rε,eigenvalues,residuals,eigenvectors,num

    
end    



  
@time rε,eigenvalues,residuals,eigenvectors,num = main()



println("Eigenvalues are calculated!")




#println(ε)
#println(N)
#println(eigenvalues)
# Out:
# Julia Version 0.6.4
# Commit 9d11f62bcb (2018-07-09 19:09 UTC)
# Platform Info:
#   OS: macOS (x86_64-apple-darwin14.5.0)
#   CPU: Intel(R) Xeon(R) CPU E5-1680 v2 @ 3.00GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (USE64BITINT DYNAMIC_ARCH NO_AFFINITY Sandybridge MAX_THREADS=16)
#   LAPACK: libopenblas64_
#   LIBM: libopenlibm
#   LLVM: libLLVM-3.9.1 (ORCJIT, ivybridge)
# Dimension of the matrix: 288
# Doing the full diagonalization...
#   0.258026 seconds (23.95 k allocations: 3.708 MiB)
# Done
# 1       -0.11777819799874845
# 2       -0.1099878708265063
# 3       -0.10235919963593076
# 4       -0.08834928526238794
# 5       -0.07960927272439644
# 6       -0.023028371717424
# 7       -0.013189559224455749
# 8       0.013189559224455749
# 9       0.02302837171742933
# 10       0.07960927272439466
# 11       0.08834928526238617
# 12       0.10235919963592899
# 13       0.10998787082650363
# 14       0.11777819799874756
# Doing the SS method...
# Estimating number of eigenvalues...
# ------------------------------------------------------------
# i = 1/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.9793415257901056e-13
# Num. of iterations = 414
# --------------------------------------------------------
# i = 2/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.196745998473826e-13
# Num. of iterations = 410
# --------------------------------------------------------
# i = 3/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 5.107202409312502e-13
# Num. of iterations = 382
# --------------------------------------------------------
# i = 4/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.814452145051814e-13
# Num. of iterations = 381
# --------------------------------------------------------
# i = 5/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.962396662418135e-13
# Num. of iterations = 387
# --------------------------------------------------------
# i = 6/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 1.9562092348905945e-13
# Num. of iterations = 401
# --------------------------------------------------------
# i = 7/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.960128100561919e-13
# Num. of iterations = 392
# --------------------------------------------------------
# i = 8/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.007471931181647e-13
# Num. of iterations = 399
# --------------------------------------------------------
# i = 9/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.575863268278053e-13
# Num. of iterations = 379
# --------------------------------------------------------
# i = 10/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 5.600662579901646e-13
# Num. of iterations = 403
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
# Estimated number of eigenvalues: 15
# L is 3
# Calculating eigenvalues and eigenvectors...
# ------------------------------------------------------------
# i = 1/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.281090816272633e-13
# Num. of iterations = 396
# --------------------------------------------------------
# i = 2/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 5.734769262185604e-13
# Num. of iterations = 382
# --------------------------------------------------------
# i = 3/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.933930132171472e-13
# Num. of iterations = 381
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
#   7.671814 seconds (5.67 M allocations: 11.907 GiB, 18.87% gc time)
# done.
# number    eigenvalue    residual    original     difference
# 1     -0.1177781979987473    2.363076305855395e-9     -0.11777819799874845    1.1518563880486e-15
# 2     -0.10998787082650441    1.4374486935211745e-9     -0.1099878708265063    1.887379141862766e-15
# 3     -0.1023591996359294    2.447291242378116e-10     -0.10235919963593076    1.3600232051658168e-15
# 4     -0.08834928526238654    1.8260998365294143e-9     -0.08834928526238794    1.4016565685892601e-15
# 5     -0.07960927272439511    3.5892849139110774e-9     -0.07960927272439644    1.3322676295501878e-15
# 6     -0.02302837171743019    4.214053557323766e-9     -0.023028371717424    -6.189493362285248e-15
# 7     -0.013189559224455125    2.3696727753957863e-9     -0.013189559224455749    6.245004513516506e-16
# 8     0.013189559224455166    2.7742532737167445e-9     0.013189559224455749    -5.828670879282072e-16
# 9     0.023028371717430135    6.027595700097588e-9     0.02302837171742933    8.049116928532385e-16
# 10     0.07960927272439491    2.0101043777157616e-8     0.07960927272439466    2.498001805406602e-16
# 11     0.08834928526238661    1.656343170395269e-8     0.08834928526238617    4.440892098500626e-16
# 12     0.10235919963592924    2.9262780302299038e-9     0.10235919963592899    2.498001805406602e-16
# 13     0.10998787082650446    5.209208700334712e-9     0.10998787082650363    8.326672684688674e-16
# 14     0.11777819799874714    2.73499724282078e-9     0.11777819799874756    -4.163336342344337e-16
# -----------------------------------------
#  10.662873 seconds (7.67 M allocations: 12.004 GiB, 13.98% gc time)
# Eigenvalues are calculated!
