# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
@everywhere include("SS_p.jl")
@everywhere import SS



function make_1Dtb(N,periodic=true) #1D tight binding model
    mat_H = spzeros(N,N)
    t = 1.0
    
    for i in 1:N
        for dx in -1:1
            j = i + dx
            if periodic
                if j > N
                    j = j -N
                elseif j < 1
                    j = j +N
                end
            end
            
            if 1 <= j <= N
                if dx == 1
                    mat_H[i,j] = -t
                elseif dx == -1
                    mat_H[i,j] = -t
                elseif dx ==0
                    mat_H[i,j] = 1.5
                end
                    
            end
            
        end
    end
    
    return mat_H
end


function make_2Dtb(Nx,Ny,periodic=true) #2D tight binding model
    mat_H = spzeros(Nx*Ny,Nx*Ny)
    t = 1.0
    μ = -1.5
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end
                        i = (iy-1)*Nx+ix
                        j = (jy-1)*Ny+jx
                        mat_H[i,j] = v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end


function make_2Dtbsc(Nx,Ny,periodic=true) #2D tight binding model with superconducting SNS π junction
    mat_H = spzeros(Nx*Ny*2,Nx*Ny*2)
    N = Nx*Ny
    t = 1.0
    μ = -1.5
    Δ = 1.0
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    i = (iy-1)*Nx+ix
                    j = (jy-1)*Ny+jx
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ                                
                                vd = ifelse(jx < Nx/2,Δ,-Δ)
                                
                                if Nx/2-Nx/6 <= jx <= Nx/2 + Nx/6
                                  vd = 0.0  
                                end
                                mat_H[i,j+N] = vd
                                mat_H[i+N,j] = vd                                   
                                    
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end

                        mat_H[i,j] = v
                        mat_H[i+N,j+N] = -v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end




function main()
    Nx = 12
    Ny = 12

    
    ρ = 0.2
    γ = 0.0
    ε =0
#    mat_H = make_1Dtb(N) #1D system
    N = Nx*Ny
#    mat_H = make_2Dtb(Nx,Ny,false) #2D system
    N = Nx*Ny*2
    mat_H = make_2Dtbsc(Nx,Ny,false) #2D system with superconducting SNS π-junction
    
    println("Dimension of the matrix: ",N)
    rε = Float64[]
    if N <= 8192
        println("Doing the full diagonalization...")
        @time ε,vec_w = eig(full(mat_H))
        println("Done")
        

        integers = Int64[]
        for i in 1:N
            push!(integers,i)
        end      
        
        
        rε = Float64[]
        is = 0
        for i in 1:N
            if γ-ρ <= ε[i] <= γ+ρ
                is += 1
                push!(rε,ε[i])
            end
        end         
    end
   

   

    #println(ε)
    if N < 2000
      
        for i in 1:is
            println(i, "       ",rε[i])
        end
       
        
    end
    

    
    #println(typeof(mat_H[1,1]))
    println("Doing the SS method...")
    @time eigenvalues,residuals,eigenvectors,num = SS.eigensystem(mat_H,N,ρ,γ)
    println("done.")
    
    if N <= 8192
        println("number    eigenvalue    residual    original     difference")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i],"     ",rε[i], "    ",eigenvalues[i]-rε[i])
        end
    else
        println("number    eigenvalue    residual    ")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i])
        end        
    end
    println("-----------------------------------------") 
#plot(integers[:],ε[:],label="Original") 
#    plot(integers[1:num],eigenvalues[1:num],label="SS method") 

#    plot(integers[1:N],ε[1:N],label="Original")      
    
    return rε,eigenvalues,residuals,eigenvectors,num

    
end    



  
@time rε,eigenvalues,residuals,eigenvectors,num = main()



println("Eigenvalues are calculated!")




#println(ε)
#println(N)
#println(eigenvalues)
# Out:
# Dimension of the matrix: 288
# Doing the full diagonalization...
#   0.097722 seconds (26 allocations: 2.636 MiB)
# WARNING: replacing module shiftedcg
# WARNING: replacing module SS
# Done
# 1       -0.11777819799874933
# 2       -0.1099878708265063
# 3       -0.10235919963593076
# 4       -0.08834928526238972
# 5       -0.07960927272439733
# 6       -0.02302837171742489
# 7       -0.013189559224457525
# 8       0.013189559224454861
# 9       0.02302837171742933
# 10       0.07960927272439289
# 11       0.08834928526238617
# 12       0.10235919963592632
# 13       0.10998787082650185
# 14       0.11777819799874667
# Doing the SS method...
# Estimating number of eigenvalues...
# ------------------------------------------------------------
# i = 1/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 1.5571090037475822e-13
# Num. of iterations = 387
# --------------------------------------------------------
# i = 2/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 1.8633735526785748e-14
# Num. of iterations = 389
# --------------------------------------------------------
# i = 3/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 8.051276319449959e-13
# Num. of iterations = 383
# --------------------------------------------------------
# i = 4/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.169798291264209e-13
# Num. of iterations = 407
# --------------------------------------------------------
# i = 5/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 8.630461881982778e-13
# Num. of iterations = 384
# --------------------------------------------------------
# i = 6/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.892977116181875e-13
# Num. of iterations = 385
# --------------------------------------------------------
# i = 7/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.772269830282332e-13
# Num. of iterations = 383
# --------------------------------------------------------
# i = 8/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.2525240807688773e-13
# Num. of iterations = 404
# --------------------------------------------------------
# i = 9/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 9.962666378248183e-13
# Num. of iterations = 387
# --------------------------------------------------------
# i = 10/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.33417524247487e-13
# Num. of iterations = 403
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
# Estimated number of eigenvalues: 15
# L is 3
# Calculating eigenvalues and eigenvectors...
# ------------------------------------------------------------
# i = 1/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.0880467328678773e-13
# Num. of iterations = 396
# --------------------------------------------------------
# i = 2/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.2710044650473496e-13
# Num. of iterations = 395
# --------------------------------------------------------
# i = 3/3
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.5213982458869366e-13
# Num. of iterations = 379
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
#  10.429962 seconds (6.01 M allocations: 13.274 GiB, 22.86% gc time)
# done.
# number    eigenvalue    residual    original     difference
# 1     -0.11777819799874722    6.712860496000031e-9     -0.11777819799874933    2.1094237467877974e-15
# 2     -0.10998787082650407    1.5415775707408438e-8     -0.1099878708265063    2.220446049250313e-15
# 3     -0.10235919963592932    7.995124988651168e-9     -0.10235919963593076    1.4432899320127035e-15
# 4     -0.0883492852623865    6.684377743900653e-10     -0.08834928526238972    3.219646771412954e-15
# 5     -0.07960927272439511    4.159257557579385e-9     -0.07960927272439733    2.220446049250313e-15
# 6     -0.023028371717430163    2.0668886403498265e-9     -0.02302837171742489    -5.2735593669694936e-15
# 7     -0.013189559224454861    4.1074245516718285e-8     -0.013189559224457525    2.6645352591003757e-15
# 8     0.013189559224455388    1.3953125776858146e-8     0.013189559224454861    5.273559366969494e-16
# 9     0.023028371717430135    7.54216403404361e-9     0.02302837171742933    8.049116928532385e-16
# 10     0.07960927272439508    2.0689027975213357e-9     0.07960927272439289    2.192690473634684e-15
# 11     0.08834928526238661    4.5701573236956435e-9     0.08834928526238617    4.440892098500626e-16
# 12     0.10235919963592968    9.87326055025378e-10     0.10235919963592632    3.3584246494910985e-15
# 13     0.10998787082650455    6.2527113072713796e-9     0.10998787082650185    2.6922908347160046e-15
# 14     0.11777819799874747    3.0685417991309165e-9     0.11777819799874667    8.049116928532385e-16
# -----------------------------------------
#  12.006692 seconds (6.62 M allocations: 13.306 GiB, 20.29% gc time)
# Eigenvalues are calculated!

# %%
println(64*64*2,",",48*48*2,",",28.940373*(64*64/(48*48))^3)
170
# Out:
# 8192,4608,162.60599150617284
# 170

# %%
println(64*64*2,",",48*48*2,",",28.940373*(96*96/(48*48))^3)
println(64*64*2,",",48*48*2,",",28.940373*(72*72/(48*48))^3)
# Out:
# 8192,4608,1852.183872
# 8192,4608,329.648936203125
