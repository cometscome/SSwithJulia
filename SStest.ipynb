# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
include("SS.jl")
import SS



function make_1Dtb(N,periodic=true) #1D tight binding model
    mat_H = spzeros(N,N)
    t = 1.0
    
    for i in 1:N
        for dx in -1:1
            j = i + dx
            if periodic
                if j > N
                    j = j -N
                elseif j < 1
                    j = j +N
                end
            end
            
            if 1 <= j <= N
                if dx == 1
                    mat_H[i,j] = -t
                elseif dx == -1
                    mat_H[i,j] = -t
                elseif dx ==0
                    mat_H[i,j] = 1.5
                end
                    
            end
            
        end
    end
    
    return mat_H
end


function make_2Dtb(Nx,Ny,periodic=true) #2D tight binding model
    mat_H = spzeros(Nx*Ny,Nx*Ny)
    t = 1.0
    μ = -1.5
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end
                        i = (iy-1)*Nx+ix
                        j = (jy-1)*Ny+jx
                        mat_H[i,j] = v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end


function make_2Dtbsc(Nx,Ny,periodic=true) #2D tight binding model with superconducting SNS π junction
    mat_H = spzeros(Nx*Ny*2,Nx*Ny*2)
    N = Nx*Ny
    t = 1.0
    μ = -1.5
    Δ = 1.0
    
    for ix in 1:Nx
        for iy in 1:Nx
            for dx in -1:1
                for dy in -1:1
                    jx = ix + dx
                    jy = iy + dy
                    v = 0.0
                    if periodic
                        if jx > Nx
                            jx = jx - Nx
                        elseif jx < 1
                            jx = jx + Nx
                        end
                        if jy > Ny
                            jy = jy - Ny
                        elseif jy < 1
                            jy = jy + Ny
                        end                        
                    end
                    i = (iy-1)*Nx+ix
                    j = (jy-1)*Ny+jx
                    if 1 <= jx <= Nx && 1 <= jy <= Ny
                        if dx == 0 
                            if dy == 0
                                v = -μ                                
                                vd = ifelse(jx < Nx/2,Δ,-Δ)
                                
                                if Nx/2-Nx/6 <= jx <= Nx/2 + Nx/6
                                  vd = 0.0  
                                end
                                mat_H[i,j+N] = vd
                                mat_H[i+N,j] = vd                                   
                                    
                            elseif dy == 1
                                v = -t
                            elseif dy == -1
                                v = -t
                            end
                        elseif dx == 1                            
                            if dy == 0
                                v = -t
                            end
                        elseif dx == -1                            
                            if dy == 0
                                v = -t
                            end
                        end

                        mat_H[i,j] = v
                        mat_H[i+N,j+N] = -v
                    end
                end
            end
        end
    end

    
    
    return mat_H
end




function main()
    Nx = 24
    Ny = 24

    
    ρ = 0.2
    γ = 0.0
    ε =0
#    mat_H = make_1Dtb(N) #1D system
    N = Nx*Ny
#    mat_H = make_2Dtb(Nx,Ny,false) #2D system
    N = Nx*Ny*2
    mat_H = make_2Dtbsc(Nx,Ny,false) #2D system with superconducting SNS π-junction
    
    println("Dimension of the matrix: ",N)
    rε = Float64[]
    if N <= 8192
        println("Doing the full diagonalization...")
        @time ε,vec_w = eig(full(mat_H))
        println("Done")
        

        integers = Int64[]
        for i in 1:N
            push!(integers,i)
        end      
        
        
        rε = Float64[]
        is = 0
        for i in 1:N
            if γ-ρ <= ε[i] <= γ+ρ
                is += 1
                push!(rε,ε[i])
            end
        end         
    end
   

   

    #println(ε)
    if N < 2000
      
        for i in 1:is
            println(i, "       ",rε[i])
        end
       
        
    end
    

    
    #println(typeof(mat_H[1,1]))
    println("Doing the SS method...")
    @time eigenvalues,residuals,eigenvectors,num = SS.eigensystem(mat_H,N,ρ,γ)
    println("done.")
    
    if N <= 8192
        println("number    eigenvalue    residual    original     difference")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i],"     ",rε[i], "    ",eigenvalues[i]-rε[i])
        end
    else
        println("number    eigenvalue    residual    ")
        for i in 1:num
            println(i,"     ",eigenvalues[i],"    ",residuals[i])
        end        
    end
    println("-----------------------------------------") 
#plot(integers[:],ε[:],label="Original") 
#    plot(integers[1:num],eigenvalues[1:num],label="SS method") 

#    plot(integers[1:N],ε[1:N],label="Original")      
    
    return rε,eigenvalues,residuals,eigenvectors,num

    
end    




    
rε,eigenvalues,residuals,eigenvectors,num = main()



println("Eigenvalues are calculated!")




#println(ε)
#println(N)
#println(eigenvalues)
# Out:
# Dimension of the matrix: 1152
# Doing the full diagonalization...
# WARNING: replacing module shiftedcg
# WARNING: replacing module SS
#  0.855862 seconds (27 allocations: 40.914 MiB, 1.03% gc time)
# Done
# 1       -0.19666940093484006
# 2       -0.08264591838193554
# 3       -0.08152480797464068
# 4       -0.07732498220184277
# 5       -0.07685141031094428
# 6       -0.07410545260504214
# 7       -0.07235636846473724
# 8       -0.07188004972316192
# 9       -0.060821813749373455
# 10       -0.04743437216302259
# 11       -0.04252786554657509
# 12       -0.033831138727866694
# 13       -0.017893632607488084
# 14       -0.015704022062804326
# 15       -0.0009854974493847405
# 16       0.0009854974493841149
# 17       0.015704022062803868
# 18       0.01789363260748712
# 19       0.03383113872786492
# 20       0.04252786554657599
# 21       0.04743437216302316
# 22       0.06082181374937168
# 23       0.07188004972316255
# 24       0.07235636846473775
# 25       0.07410545260504275
# 26       0.07685141031094228
# 27       0.07732498220184363
# 28       0.08152480797464001
# 29       0.08264591838193436
# 30       0.19666940093484087
# Doing the SS method...
# Estimating number of eigenvalues...
# ------------------------------------------------------------
# i = 1/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.99891874229317e-13
# Num. of iterations = 1255
# --------------------------------------------------------
# i = 2/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.518012912682693e-13
# Num. of iterations = 1299
# --------------------------------------------------------
# i = 3/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 9.224490662350937e-13
# Num. of iterations = 1323
# --------------------------------------------------------
# i = 4/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 1.8161824444880072e-13
# Num. of iterations = 1291
# --------------------------------------------------------
# i = 5/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.706855836070828e-13
# Num. of iterations = 1306
# --------------------------------------------------------
# i = 6/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 9.21459848560466e-13
# Num. of iterations = 1301
# --------------------------------------------------------
# i = 7/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.3831632012576553e-13
# Num. of iterations = 1253
# --------------------------------------------------------
# i = 8/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.204723253770981e-13
# Num. of iterations = 1259
# --------------------------------------------------------
# i = 9/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 2.6169277174243917e-14
# Num. of iterations = 1221
# --------------------------------------------------------
# i = 10/10
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.33384508502955e-13
# Num. of iterations = 1306
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
# Estimated number of eigenvalues: 28
# L is 7
# Calculating eigenvalues and eigenvectors...
# ------------------------------------------------------------
# i = 1/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.3887056844548964e-14
# Num. of iterations = 1229
# --------------------------------------------------------
# i = 2/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.780512133385421e-13
# Num. of iterations = 1313
# --------------------------------------------------------
# i = 3/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 5.31580260480952e-13
# Num. of iterations = 1299
# --------------------------------------------------------
# i = 4/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 5.554596297671037e-13
# Num. of iterations = 1287
# --------------------------------------------------------
# i = 5/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 6.135138369701549e-13
# Num. of iterations = 1272
# --------------------------------------------------------
# i = 6/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 4.5134044361067613e-13
# Num. of iterations = 1291
# --------------------------------------------------------
# i = 7/7
# --------------------------------------------------------
# Solving linear equations with the shifted CG method...
# done.
# error = 3.535527658494779e-13
# Num. of iterations = 1277
# --------------------------------------------------------
# done.
# ------------------------------------------------------------
# 123.230614 seconds (67.36 M allocations: 340.633 GiB, 34.14% gc time)
# done.
# number    eigenvalue    residual    original     difference
# 1     -0.19666946218923015    5.660423248516487e-6     -0.19666940093484006    -6.125439008797251e-8
# 2     -0.0826458970681847    0.0003109805314394404     -0.08264591838193554    2.13137508336958e-8
# 3     -0.08152478893628279    0.00012394099867235565     -0.08152480797464068    1.9038357890188706e-8
# 4     -0.07732499303694432    0.00037471721907133654     -0.07732498220184277    -1.083510155208689e-8
# 5     -0.07685139981653093    0.000723638597355329     -0.07685141031094428    1.049441335221335e-8
# 6     -0.07410547863610573    0.00033380839244668626     -0.07410545260504214    -2.603106358245455e-8
# 7     -0.07235635892709288    0.00023176919250048733     -0.07235636846473724    9.53764435485116e-9
# 8     -0.07188004423926227    0.0003914198946360225     -0.07188004972316192    5.483899653824231e-9
# 9     -0.06082181495329053    0.0009665382634047931     -0.060821813749373455    -1.2039170771416252e-9
# 10     -0.04743436784823818    0.0012674506382523523     -0.04743437216302259    4.314784411707517e-9
# 11     -0.042527862829355945    0.0013869456777759147     -0.04252786554657509    2.7172191441326987e-9
# 12     -0.03383114200644444    0.005525444286316184     -0.033831138727866694    -3.2785777426269647e-9
# 13     -0.01789363084570217    0.0024870746309892523     -0.017893632607488084    1.7617859150720339e-9
# 14     -0.01570402047238728    0.006733248901300331     -0.015704022062804326    1.5904170445890653e-9
# 15     -0.000985497374375921    0.03700051077065545     -0.0009854974493847405    7.500881946814753e-11
# 16     0.000985497241930533    0.037073374322641725     0.0009854974493841149    -2.074535818737816e-10
# 17     0.01570401974546254    0.0005358424506712601     0.015704022062803868    -2.3173413292443268e-9
# 18     0.01789362860935695    0.000973205613578027     0.01789363260748712    -3.998130170684844e-9
# 19     0.033831131081600185    0.0007021218873933671     0.03383113872786492    -7.646264732485974e-9
# 20     0.04252786479747961    0.0008455482091909148     0.04252786554657599    -7.490963821465968e-10
# 21     0.04743437701918418    0.0005236534320784956     0.04743437216302316    4.8561610219155504e-9
# 22     0.060821819485394446    0.0005323055998250215     0.06082181374937168    5.7360227678771025e-9
# 23     0.07188005060533337    0.002680785763133208     0.07188004972316255    8.82170822502637e-10
# 24     0.07235636807440193    0.0006621832718636773     0.07235636846473775    -3.9033581922254257e-10
# 25     0.07410543721458962    0.0016043952435528758     0.07410545260504275    -1.5390453134145332e-8
# 26     0.07685140553939034    0.0004986639648556029     0.07685141031094228    -4.771551945226271e-9
# 27     0.07732498551038917    0.0006208360539130356     0.07732498220184363    3.3085455486414617e-9
# 28     0.08152483078959094    0.00046087295682533205     0.08152480797464001    2.2814950928484734e-8
# 29     0.08264591220672335    0.0006581068475671653     0.08264591838193436    -6.17521100920726e-9
# 30     0.19666942523406394    3.518565849884201e-6     0.19666940093484087    2.4299223078116938e-8
# -----------------------------------------
# Eigenvalues are calculated!

# %%
println(64*64*2,",",48*48*2,",",28.940373*(64*64/(48*48))^3)
170
# Out:
# 8192,4608,162.60599150617284
# 170

# %%
println(64*64*2,",",48*48*2,",",28.940373*(96*96/(48*48))^3)
println(64*64*2,",",48*48*2,",",28.940373*(72*72/(48*48))^3)
# Out:
# 8192,4608,1852.183872
# 8192,4608,329.648936203125
